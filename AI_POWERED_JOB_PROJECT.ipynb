# %% [markdown]
# <a href="https://colab.research.google.com/github/patelShiv84/AI-POWERED-JOB-ANALYSIS/blob/main/AI_POWERED_JOB_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ⏬ **AI-POWERED JOB ANALYSIS PROJECT**
# ---

# %% [markdown]
# # **⏩ IMPORT LIBRARIES**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk
import scipy as sp
import plotly.express as px

# %% [markdown]
# # **⏩ READ A DATASET**

# %%
ai_job = pd.read_csv('/content/drive/MyDrive/DATASET/extended_ai_job_market_insights (1).csv')
ai_job.head()
# Out:
#                Job_Title       Industry Company_Size   Location  \
# 0  Cybersecurity Analyst  Entertainment        Small      Dubai
# 1   Marketing Specialist     Technology        Large  Singapore
# 2          AI Researcher     Technology          NaN  Singapore
# 3          Sales Manager         Retail        Small     Berlin
# 4  Cybersecurity Analyst  Entertainment        Small      Tokyo
#
#   AI_Adoption_Level Automation_Risk     Required_Skills     Salary_USD  \
# 0            Medium            High        UX/UI Design  111392.165243
# 1            Medium            High           Marketing   93792.562466
# 2            Medium             NaN        UX/UI Design  107170.263069
# 3               Low            High  Project Management   93027.953758
# 4               NaN             Low          JavaScript   87752.922171
#
#   Remote_Friendly Job_Growth_Projection
# 0             Yes                Growth
# 1              No                   NaN
# ...

# %% [markdown]
# # **⏩ BASIC INFORMATION OF DATASET**

# %%
ai_job.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Job_Title              20000 non-null  object
#  1   Industry               20000 non-null  object
#  2   Company_Size           18670 non-null  object
#  3   Location               20000 non-null  object
#  4   AI_Adoption_Level      18881 non-null  object
#  5   Automation_Risk        18680 non-null  object
#  6   Required_Skills        20000 non-null  object
#  7   Salary_USD             20000 non-null  float64
#  8   Remote_Friendly        19236 non-null  object
#  9   Job_Growth_Projection  18889 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 1.5+ MB

# %%
# record and variable
ai_job.shape
# Out:
# (20000, 10)

# %%
#total size
ai_job.size
# Out:
# 200000

# %%
#total columns
ai_job.columns
# Out:
# Index(['Job_Title', 'Industry', 'Company_Size', 'Location',
#        'AI_Adoption_Level', 'Automation_Risk', 'Required_Skills', 'Salary_USD',
#        'Remote_Friendly', 'Job_Growth_Projection'],
#       dtype='object')

# %%
"""

conclusion:
->> There are 10 columns in Ai-powered job detaset and 20000  record
->> We can see only 1  numerical data "Salary_USD"

"""
# Out:
# '\n\nconclusion:\n->> There are 10 columns in Ai-powered job detaset and 20000  record\n->> We can see only 1  numerical data "Salary_USD"\n\n'

# %%
#chack a null value for each columns
ai_job.isnull().sum()
# Out:
# Job_Title                   0
# Industry                    0
# Company_Size             1330
# Location                    0
# AI_Adoption_Level        1119
# Automation_Risk          1320
# Required_Skills             0
# Salary_USD                  0
# Remote_Friendly           764
# Job_Growth_Projection    1111
# dtype: int64

# %%
"""
conclusion:

--> There are available a null value in "Company_Size", "AI_Adoption_Level", "Automation_Risk", "Remote_Friendly", "Job_Growth_Projection"

--> It will remove on next step

"""
# Out:
# '\nconclusion:\n\n--> There are available a null value in "Company_Size", "AI_Adoption_Level", "Automation_Risk", "Remote_Friendly", "Job_Growth_Projection"\n\n--> It will remove on next step\n\n'

# %%
ai_job.Job_Title.unique()
# Out:
# array(['Cybersecurity Analyst', 'Marketing Specialist', 'AI Researcher',
#        'Sales Manager', 'UX Designer', 'HR Manager', 'Product Manager',
#        'Software Engineer', 'Data Scientist', 'Operations Manager'],
#       dtype=object)

# %%
ai_job.Job_Title.value_counts().sort_values(ascending=False)
# Out:
# Job_Title
# Data Scientist           2426
# Cybersecurity Analyst    2225
# HR Manager               2209
# UX Designer              2143
# AI Researcher            2087
# Sales Manager            2037
# Marketing Specialist     1947
# Operations Manager       1701
# Software Engineer        1667
# Product Manager          1558
# Name: count, dtype: int64

# %%
"""
conclusion:

--> There are the all type of job title in dataset :

['Cybersecurity Analyst',
'Marketing Specialist',
'AI Researcher',
'Sales Manager',
'UX Designer',
'HR Manager',
'Product Manager',
'Software Engineer',
'Data Scientist',
'Operations Manager']

--> "Data Scientist" have high count in dataset
--> "product manager" have low count in dataset

"""
# Out:
# '\nconclusion:\n\n--> There are the all type of job title in dataset :\n\n[\'Cybersecurity Analyst\',\n\'Marketing Specialist\',\n\'AI Researcher\',\n\'Sales Manager\',\n\'UX Designer\',\n\'HR Manager\',\n\'Product Manager\',\n\'Software Engineer\',\n\'Data Scientist\',\n\'Operations Manager\']\n\n--> "Data Scientist" have high count in dataset\n--> "product manager" have low count in dataset\n\n'

# %%
ai_job.Salary_USD.describe()
# Out:
# count     20000.000000
# mean      91257.873467
# std       20447.761832
# min       31969.526346
# 25%       78548.266723
# 50%       91850.812310
# 75%      104107.304205
# max      155209.821614
# Name: Salary_USD, dtype: float64

# %%
# Details of each column separately

for i in ai_job.columns:
    if i != 'Salary_USD':
        print('['+i+']')
        ai_job[i].value_counts().plot(kind='bar')
        plt.show()
# Out:
# [Job_Title]
# [Industry]
# [Company_Size]
# [Location]
# [AI_Adoption_Level]
# [Automation_Risk]
# [Required_Skills]
# [Remote_Friendly]
# [Job_Growth_Projection]

# %% [markdown]
# # **⏩ COPY & CLEAN DATASET**

# %%
# copy dataset for the wor
ai_job_copy = ai_job.copy()
ai_job_copy.head()
# Out:
#                Job_Title       Industry Company_Size   Location  \
# 0  Cybersecurity Analyst  Entertainment        Small      Dubai
# 1   Marketing Specialist     Technology        Large  Singapore
# 2          AI Researcher     Technology          NaN  Singapore
# 3          Sales Manager         Retail        Small     Berlin
# 4  Cybersecurity Analyst  Entertainment        Small      Tokyo
#
#   AI_Adoption_Level Automation_Risk     Required_Skills     Salary_USD  \
# 0            Medium            High        UX/UI Design  111392.165243
# 1            Medium            High           Marketing   93792.562466
# 2            Medium             NaN        UX/UI Design  107170.263069
# 3               Low            High  Project Management   93027.953758
# 4               NaN             Low          JavaScript   87752.922171
#
#   Remote_Friendly Job_Growth_Projection
# 0             Yes                Growth
# 1              No                   NaN
# ...

# %% [markdown]
# # **⏩ REMOVE NULL VALUE**

# %%
ai_job_copy.isnull().sum()
# Out:
# Job_Title                   0
# Industry                    0
# Company_Size             1330
# Location                    0
# AI_Adoption_Level        1119
# Automation_Risk          1320
# Required_Skills             0
# Salary_USD                  0
# Remote_Friendly           764
# Job_Growth_Projection    1111
# dtype: int64

# %%
# [Step:1] "Company_Size"
# There are "1330" value are missing in "Company_Size"
# This is a categorical data so we can fill by "frequency"

# %%
ai_job_copy.Company_Size.value_counts()
# Out:
# Company_Size
# Small     6456
# Large     6233
# Medium    5981
# Name: count, dtype: int64

# %%
# In the "company_size" "small" have high "frequency" so we fill
ai_job_copy.Company_Size.fillna('Small', inplace=True)
# Out:
# <ipython-input-59-fdfe2521b8aa>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ai_job_copy.Company_Size.fillna('Small', inplace=True)

# %%
ai_job_copy.isnull().sum()
# Out:
# Job_Title                   0
# Industry                    0
# Company_Size                0
# Location                    0
# AI_Adoption_Level        1119
# Automation_Risk          1320
# Required_Skills             0
# Salary_USD                  0
# Remote_Friendly           764
# Job_Growth_Projection    1111
# dtype: int64

# %%
# [Step:2] "AI_Adoption_Level"
# There are "1119" value are missing in "AI_Adoption_Level"
# This is a categorical data so we can fill by "ffill"

# %%
ai_job_copy['AI_Adoption_Level'].ffill(axis="rows",inplace=True)
# Out:
# <ipython-input-62-d3dfebfa5b71>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ai_job_copy['AI_Adoption_Level'].ffill(axis="rows",inplace=True)

# %%
ai_job_copy.isnull().sum()
# Out:
# Job_Title                   0
# Industry                    0
# Company_Size                0
# Location                    0
# AI_Adoption_Level           0
# Automation_Risk          1320
# Required_Skills             0
# Salary_USD                  0
# Remote_Friendly           764
# Job_Growth_Projection    1111
# dtype: int64

# %%
# [Step:3] "Automation_Risk"
# There are "1119" value are missing in "Automation_Risk"
# This is a categorical data so we can fill by "bfill"

# %%
ai_job_copy['Automation_Risk'].bfill(axis="rows",inplace=True)
# Out:
# <ipython-input-65-d746c70a2f37>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ai_job_copy['Automation_Risk'].bfill(axis="rows",inplace=True)

# %%
ai_job_copy.isnull().sum()
# Out:
# Job_Title                   0
# Industry                    0
# Company_Size                0
# Location                    0
# AI_Adoption_Level           0
# Automation_Risk             0
# Required_Skills             0
# Salary_USD                  0
# Remote_Friendly           764
# Job_Growth_Projection    1111
# dtype: int64

# %%
# [Step:4] "Remote_Friendly"
# There are "1119" value are missing in "Remote_Friendly"
# This is a categorical data so we can fill by "bfill"

# %%
ai_job_copy['Remote_Friendly'].bfill(axis="rows",inplace=True)
# Out:
# <ipython-input-68-4ae632025c65>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ai_job_copy['Remote_Friendly'].bfill(axis="rows",inplace=True)

# %%
ai_job_copy.isnull().sum()
# Out:
# Job_Title                   0
# Industry                    0
# Company_Size                0
# Location                    0
# AI_Adoption_Level           0
# Automation_Risk             0
# Required_Skills             0
# Salary_USD                  0
# Remote_Friendly             0
# Job_Growth_Projection    1111
# dtype: int64

# %%
# [Step:5] "Job_Growth_Projection"
# There are "1111" value are missing in "Job_Growth_Projection"
# This is a categorical data so we can fill by "frequency"

# %%
ai_job_copy.Job_Growth_Projection.value_counts()
# Out:
# Job_Growth_Projection
# Decline    6443
# Growth     6337
# Stable     6109
# Name: count, dtype: int64

# %%
# In the "company_size" "small" have high "frequency" so we fill
ai_job_copy.Job_Growth_Projection.fillna('Decline', inplace=True)
# Out:
# <ipython-input-72-922970373e74>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ai_job_copy.Job_Growth_Projection.fillna('Decline', inplace=True)

# %%
ai_job_copy.isnull().sum()
# Out:
# Job_Title                0
# Industry                 0
# Company_Size             0
# Location                 0
# AI_Adoption_Level        0
# Automation_Risk          0
# Required_Skills          0
# Salary_USD               0
# Remote_Friendly          0
# Job_Growth_Projection    0
# dtype: int64

# %%
ai_job_copy.head()
# Out:
#                Job_Title       Industry Company_Size   Location  \
# 0  Cybersecurity Analyst  Entertainment        Small      Dubai
# 1   Marketing Specialist     Technology        Large  Singapore
# 2          AI Researcher     Technology        Small  Singapore
# 3          Sales Manager         Retail        Small     Berlin
# 4  Cybersecurity Analyst  Entertainment        Small      Tokyo
#
#   AI_Adoption_Level Automation_Risk     Required_Skills     Salary_USD  \
# 0            Medium            High        UX/UI Design  111392.165243
# 1            Medium            High           Marketing   93792.562466
# 2            Medium            High        UX/UI Design  107170.263069
# 3               Low            High  Project Management   93027.953758
# 4               Low             Low          JavaScript   87752.922171
#
#   Remote_Friendly Job_Growth_Projection
# 0             Yes                Growth
# 1              No               Decline
# ...

# %% [markdown]
# # **⏩ BASIC DATA VISUALIZATION**

# %% [markdown]
# # ⏬ 1. count for each job title

# %%
value_counts = ai_job_copy['Job_Title'].value_counts().reset_index()
value_counts
value_counts.columns = ['Job_Title', 'Count']
fig = px.pie(
    value_counts,
    names='Job_Title',
    values='Count',
    title='Distribution of Job_Title',
    color_discrete_sequence=px.colors.sequential.Plasma
)
fig.update_layout(
    title_x=0.5
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
"""
Conclusion:
▶️ Count for each Job Title:

-->The analysis reveals a significant demand for Data Scientists in the AI job market, emphasizing their crucial role in extracting insights and driving innovation.

-->While other roles like AI Researchers and Software Engineers are also present, the dominance of Data Scientists indicates a strong focus on data-driven decision-making within AI-powered organizations.

--> This trend highlights the importance of data expertise in the evolving AI landscape and suggests that individuals with data science skills will be highly sought after in the future.
"""

# %% [markdown]
# # ⏬ 2. count for each Industry

# %%
value_counts = ai_job_copy['Industry'].value_counts().reset_index()
value_counts
value_counts.columns = ['Industry', 'Count']
fig = px.pie(
    value_counts,
    names='Industry',
    values='Count',
    title='Distribution of Industry',
    color_discrete_sequence=px.colors.sequential.Plasma
)
fig.update_layout(
    title_x=0.5
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
"""
conclusion:
▶️ Count for each Industry:

--> The IT industry emerges as the dominant player in the AI job market, attracting a large concentration of AI-related roles and expertise.

--> This signifies the industry's significant investment in AI technologies and its role in shaping AI advancements.

--> Other industries, such as Finance and Healthcare, also show a presence in the AI job market, albeit to a lesser extent, suggesting the gradual adoption of AI across diverse sectors.

--> This diversified adoption of AI demonstrates its potential to transform various industries and create new job opportunities in different domains.
"""

# %% [markdown]
# # ⏬ 3. Distribution of company sizes

# %%
value_counts = ai_job_copy['Company_Size'].value_counts().reset_index()
value_counts
value_counts.columns = ['Company_Size', 'Count']
fig = px.pie(
    value_counts,
    names='Company_Size',
    values='Count',
    title='Distribution of Company_Size',
    color_discrete_sequence=px.colors.sequential.Plasma
)
fig.update_layout(
    title_x=0.5
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
"""
Conclusion:

▶️ Distribution of Company Sizes:

--> The data suggests that small companies play a significant role in the AI job market, contributing to the overall growth and adoption of AI technologies.

--> While larger organizations are also involved, the considerable presence of small companies highlights their agility and willingness to embrace new innovations.

--> This emphasizes the importance of fostering a diverse ecosystem within the AI job market, where both small and large players can thrive and contribute to progress.

--> The prevalence of small companies in the AI landscape suggests a lower barrier to entry for individuals seeking AI-related careers and opportunities for rapid career growth within smaller organizations.

"""

# %% [markdown]
# # ⏬ 4. Distribution of Location

# %%
value_counts = ai_job_copy['Location'].value_counts().reset_index()
value_counts
value_counts.columns = ['Location', 'Count']
fig = px.pie(
    value_counts,
    names='Location',
    values='Count',
    title='Distribution of Location',
    color_discrete_sequence=px.colors.sequential.Plasma
)
fig.update_layout(
    title_x=0.5
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
"""
Conclusion:

▶️ Distribution of Location:

--> The analysis reveals a geographic concentration of AI-related jobs in major tech hubs like San Francisco and New York.

--> This clustering likely reflects the presence of established technology companies, research institutions, and a skilled workforce in these areas.

--> However, the data also highlights the emergence of other locations, such as Seattle and London, as potential hubs for AI talent, indicating a gradual diffusion of AI expertise across different regions.

--> This trend suggests that while certain locations may currently dominate the AI job market, opportunities are expanding in other regions, offering potential for career growth and geographic mobility for AI professionals.

"""

# %% [markdown]
# # ⏬ 5. Distribution of AI_Adoption_Level

# %%
value_counts = ai_job_copy['AI_Adoption_Level'].value_counts().reset_index()
value_counts
value_counts.columns = ['AI_Adoption_Level', 'Count']
fig = px.pie(
    value_counts,
    names='AI_Adoption_Level',
    values='Count',
    title='Distribution of AI_Adoption_Level',
    color_discrete_sequence=px.colors.sequential.Plasma
)
fig.update_layout(
    title_x=0.5
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
"""
Conclusion:

▶️ Distribution of AI Adoption Level:

--> A substantial portion of companies have either explored or implemented AI, suggesting a growing trend of AI adoption across various industries.

--> This indicates a widespread recognition of AI's potential to enhance business operations, improve decision-making, and drive innovation.

--> While the level of adoption varies, the overall trend towards AI integration signifies a significant shift in the way organizations approach technology and utilize data.

--> This shift towards AI adoption emphasizes the need for professionals to develop AI-related skills and knowledge to remain competitive in the evolving job market.

"""

# %% [markdown]
# # ⏬ 6. Distribution of Automation_Risk

# %%
value_counts = ai_job_copy['Automation_Risk'].value_counts().reset_index()
value_counts
value_counts.columns = ['Automation_Risk', 'Count']
fig = px.pie(
    value_counts,
    names='Automation_Risk',
    values='Count',
    title='Distribution of Automation_Risk',
    color_discrete_sequence=px.colors.sequential.Plasma
)
fig.update_layout(
    title_x=0.5
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
"""
Conclusion:

▶️ Distribution of Automation Risk:

--> The analysis indicates that numerous job roles face a moderate risk of automation within the next ten years, emphasizing the potential impact of AI on the workforce.

--> This highlights the need for professionals to adapt and acquire new skills to remain relevant in an evolving job market.

--> However, the data also shows that some roles have a low risk of automation, suggesting that human expertise and judgment will continue to be valuable in certain areas.

--> This underscores the importance of focusing on roles and skills that are less susceptible to automation and developing a workforce that can effectively collaborate with AI technologies.

"""

# %% [markdown]
# # ⏬ 7. Distribution of Required_Skills

# %%
value_counts = ai_job_copy['Required_Skills'].value_counts().reset_index()
value_counts
value_counts.columns = ['Required_Skills', 'Count']
fig = px.pie(
    value_counts,
    names='Required_Skills',
    values='Count',
    title='Distribution of Required_Skills',
    color_discrete_sequence=px.colors.sequential.Plasma
)
fig.update_layout(
    title_x=0.5
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
"""
Conclusion:

▶️ Distribution of Required Skills:

--> The data reveals a diverse range of skills in demand within the AI job market, with a clear emphasis on technical proficiencies like Machine Learning and Python programming.

--> This underscores the importance of acquiring strong technical skills for individuals seeking careers in AI.

--> Moreover, the data also highlights the value of soft skills, such as communication and problem-solving, indicating a need for well-rounded professionals who can collaborate effectively and adapt to evolving technologies.

--> This emphasis on both technical and soft skills suggests that successful AI professionals will need to possess a combination of specialized knowledge and interpersonal abilities to thrive in the dynamic AI landscape.

"""

# %% [markdown]
# # ⏬ 8. Distribution of Job_Growth_Projection

# %%
value_counts = ai_job_copy['Job_Growth_Projection'].value_counts().reset_index()
value_counts
value_counts.columns = ['Job_Growth_Projection', 'Count']
fig = px.pie(
    value_counts,
    names='Job_Growth_Projection',
    values='Count',
    title='Distribution of Job_Growth_Projection',
    color_discrete_sequence=px.colors.sequential.Plasma
)
fig.update_layout(
    title_x=0.5
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
"""
Conclusion:

▶️ Distribution of Job Growth Projection:

--> Despite the potential for some job categories to decline, the analysis suggests a positive outlook for job growth in the AI field.

--> Many roles are projected to experience growth, signaling significant opportunities for individuals with relevant skills and expertise.

--> This trend emphasizes the ongoing expansion of the AI industry and the increasing demand for professionals who can contribute to its development and implementation.

--> This positive job growth projection in the AI field indicates a promising career path for individuals seeking to enter or advance within this rapidly evolving industry.

"""

# %% [markdown]
# # **⏩ ADVANCE DATA VISUALIZATION**

# %% [markdown]
# # ⏬ 1. The industry related to the job and the job title.

# %%
# Group the data by job title and industry, and count the occurrences
grouped_data = ai_job_copy.groupby(['Job_Title', 'Industry'])['Job_Title'].count().reset_index(name='Count')

# Create the grouped bar plot
plt.figure(figsize=(12, 6))  # Adjust figure size as needed
sns.barplot(x='Job_Title', y='Count', hue='Industry', data=grouped_data)
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.title('Job Title vs Industry')
plt.xlabel('Job Title')
plt.ylabel('Count')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))  # Adjust legend
plt.tight_layout()
plt.show()

# %%
"""
Conclusion:

▶️ Job Title vs. Industry:

--> The analysis demonstrates a clear relationship between specific job titles and the industries where they are most prevalent.

--> This finding reveals the unique skill requirements and knowledge domains associated with different industries within the AI landscape.

--> For instance, Data Scientists are concentrated in the IT and Finance industries, while AI Researchers are more prevalent in research-intensive sectors such as Healthcare and Academia.

--> This highlights the importance of tailoring one's skills and expertise to the specific industry of interest within the AI field to maximize career opportunities and success.

"""

# %% [markdown]
# # ⏬ 2. What is Company size base on the Industry ?

# %%
# Create the grouped bar plot
plt.figure(figsize=(12, 6))  # Adjust figure size as needed
sns.countplot(x='Industry', hue='Company_Size', data=ai_job_copy)
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.title('Company Size Distribution Across Industries')
plt.xlabel('Industry')
plt.ylabel('Count')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))  # Adjust legend as needed
plt.tight_layout()
plt.show()

# %%
"""
Conclusion:

▶️ Company Size based on Industry:

--> The IT industry stands out for employing a large number of individuals across various company sizes, further confirming its position as a central hub for AI talent.

--> This indicates a robust and dynamic job market within the IT sector, with opportunities for professionals at different career stages and organizational levels.

--> The presence of AI roles across diverse company sizes in other industries suggests a gradual expansion of AI adoption and workforce diversification across the broader economy.

--> This trend signifies a growing demand for AI professionals across different industries and company sizes, providing a wide range of career options for individuals with AI-related skills.

"""

# %% [markdown]
# # ⏬ 3. What is Company size base on the job title ?

# %%
# Create the grouped bar plot
plt.figure(figsize=(12, 6))  # Adjust figure size as needed
sns.countplot(x='Job_Title', hue='Company_Size', data=ai_job_copy)
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.title('Company Size Distribution Across Industries')
plt.xlabel('Job_Title')
plt.ylabel('Count')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))  # Adjust legend as needed
plt.tight_layout()
plt.show()

# %%
"""
Conclusion:

▶️ Company Size based on Job Title:

--> Data Scientists are employed by companies of all sizes, indicating broad demand for this expertise across various organizational structures.

--> This suggests that data science skills are valuable for both large corporations and smaller startups, highlighting the versatility of this profession within the AI landscape.

--> This widespread demand for Data Scientists across different company sizes reinforces their importance in driving data-driven decision-making and innovation within organizations of all scales.

"""

# %% [markdown]
# # ⏬ 4. The estimated risk of job automation within the next ten years for each job

# %%
pd.crosstab(ai_job_copy.Job_Title , ai_job_copy.Automation_Risk).plot(kind='bar' , figsize=(15,6)  ,color=['#d1495b','#00798c','#edae49'])
plt.show()

# %%
"""
Conclusion:

▶️ Automation Risk by Job:

--> The risk of automation varies significantly by job title, reflecting the potential impact of AI on specific roles within the workforce.

--> While some jobs, such as Data Entry Clerks, face a high risk of automation, others, like AI Researchers and Data Scientists, are considered to have a lower risk.

--> This disparity emphasizes the need for professionals to carefully consider the automation potential of their chosen career paths and to focus on developing skills and expertise that are less susceptible to displacement by AI technologies.

"""

# %% [markdown]
# # ⏬ 5. The basic skills required for each job role

# %%
pd.crosstab(ai_job_copy.Job_Title , ai_job_copy.Required_Skills).plot(kind='bar' , figsize=(15,6)  )
plt.legend(bbox_to_anchor=(1, 1.5))
plt.show()

# %%
"""
Conclusion:

▶️ Basic Skills required for each job role:

--> The analysis reveals that specific skills are essential for different job roles within the AI field, highlighting the importance of acquiring the right competencies for success in specific career paths.

--> For example, Machine Learning and Deep Learning are crucial skills for AI Researchers and Data Scientists, while communication and teamwork are highly valued for roles involving collaboration and project management.

--> This emphasizes the need for individuals to identify their desired career trajectory within AI and to focus on developing the specific skills and knowledge required for those roles.

"""

# %% [markdown]
# # ⏬ 6. What is the AI_Adoption_Level base on Industry ?

# %%
plt.figure(figsize=(12, 6))  # Adjust figure size as needed
sns.countplot(x='Industry', hue='AI_Adoption_Level', data=ai_job_copy)
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.title('AI Adoption Level Across Industries')
plt.xlabel('Industry')
plt.ylabel('Count')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))  # Adjust legend as needed
plt.tight_layout()
plt.show()

# %%
"""
Conclusion:

▶️ AI Adoption Level by Industry:

--> The IT industry exhibits the highest adoption of AI, reinforcing its position at the forefront of AI advancements and applications.

--> This highlights the industry's commitment to leveraging AI technologies to enhance operations, improve products and services, and drive innovation.

--> While other industries are gradually adopting AI, the IT sector's leadership in this area underscores its importance in shaping the future of AI and its potential to attract top AI talent.

"""

# %% [markdown]
# # ⏬ 7. The estimated risk of ai automation within the next ten years for each Industry

# %%
pd.crosstab(ai_job_copy.Industry, ai_job_copy.Automation_Risk).plot(kind='bar' , figsize=(15,6)  ,color=[ "#00798c", "#d1495b", "#edae49"])
plt.show()

# %%
"""
Conclusion:

▶️ Automation Risk by Industry:

--> The Finance and Healthcare sectors face significant automation risks, indicating potential workforce transformations within these domains due to the increasing adoption of AI technologies.

--> This suggests that professionals in these industries may need to adapt and acquire new skills to remain relevant in an evolving job market.

--> However, it also presents opportunities for individuals with AI expertise to contribute to the development and implementation of automation solutions within these sectors, leading to potential career growth and innovation.

"""

# %% [markdown]
# # ⏬ 8. relation between job-title and location.

# %%
relation = pd.crosstab(ai_job_copy['Job_Title'], ai_job_copy['Location'])
print(relation)
# Out:
# Location               Berlin  Dubai  London  New York  Paris  San Francisco  \
# Job_Title
# AI Researcher              64     98     103       249     84            474
# Cybersecurity Analyst     259    388     309       234    177            174
# Data Scientist            264    256     205       302    147            251
# HR Manager                205    144     277       211    318            296
# Marketing Specialist      249    204     142        80    243            372
# Operations Manager        282    235     207       152     70            276
# Product Manager           167     80     131        75    140            257
# Sales Manager             205    106     241       102    231            214
# Software Engineer          91    204     134       204    151            129
# UX Designer               130    310      37       312    290            198
#
# Location               Singapore  Sydney  Tokyo  Toronto
# Job_Title
# ...

# %%
plt.figure(figsize=(12, 6))
sns.heatmap(pd.crosstab(ai_job_copy['Job_Title'], ai_job_copy['Location']), annot=True, cmap="YlGnBu", fmt="d")
plt.title("Relationship between Job Title and Location")
plt.xlabel("Location")
plt.ylabel("Job Title")
plt.show()

# %%
"""
Conclusion:

▶️ Job Title vs. Location:

--> Certain job titles are clustered in specific locations, revealing regional trends in the AI job market and highlighting potential career opportunities in different geographic areas.

--> For example, Data Scientists are highly concentrated in San Francisco and New York, while AI Researchers are more prevalent in cities with strong research institutions, such as Boston and Seattle.

--> This geographic distribution of AI roles emphasizes the importance of considering location preferences and job market dynamics when pursuing AI-related careers.

"""

# %% [markdown]
# # ⏬ 9. relation between job-title and AI_Adoption_Level.

# %%
pd.crosstab(ai_job_copy.Job_Title, ai_job_copy.AI_Adoption_Level).plot(kind='bar' , figsize=(15,6)  ,color=[ "#00798c", "#d1495b", "#edae49"])
plt.show()

# %%
"""
Conclusion:

▶️ Job Title vs. AI Adoption Level:

--> Data Scientist and AI Researcher roles are associated with higher AI adoption levels within organizations, suggesting that these professions are integral to the successful implementation and utilization of AI technologies.

--> This highlights the demand for professionals with expertise in these areas and their crucial role in driving AI-powered innovation within companies across various industries.

--> This finding reinforces the importance of acquiring advanced skills in data science and AI research for individuals seeking to make significant contributions to the AI field.

"""

# %% [markdown]
# # ⏬ 10. relation between job-title and Remote_Friendly.

# %%
pd.crosstab(ai_job_copy.Job_Title, ai_job_copy.Remote_Friendly).plot(kind='bar' , figsize=(15,6)  ,color=[ "#00798c", "#d1495b", "#edae49"])
plt.show()

# %%
"""
Conclusion:

▶️ Job Title vs. Remote Friendliness:

--> Many AI-related jobs, particularly those requiring specialized technical skills, offer remote work opportunities, demonstrating a shift towards flexible work arrangements in the field.

--> This trend reflects the increasing demand for AI talent and the willingness of companies to accommodate remote work options to attract and retain top professionals.

--> This flexibility in work arrangements can be attractive to individuals seeking a better work-life balance and greater geographic mobility in their AI careers.

"""

# %% [markdown]
# # ⏬ 11. relation between job-title and Job_Growth_Projection.

# %%
# Group data and calculate the count for each combination
grouped_data = ai_job_copy.groupby(['Job_Title', 'Job_Growth_Projection'])['Job_Title'].count().reset_index(name='Count')

# Create the line plot using seaborn
plt.figure(figsize=(12, 6))  # Adjust figure size as needed
sns.lineplot(x='Job_Title', y='Count', hue='Job_Growth_Projection', data=grouped_data, marker='o')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.title('Relation between Job Title and Job Growth Projection')
plt.xlabel('Job Title')
plt.ylabel('Count')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))  # Adjust legend as needed
plt.tight_layout()
plt.show()

# %%
"""
Conclusion:

▶️ Job Title vs. Job Growth Projection:

--> Data Scientists and AI Researchers are expected to experience significant job growth in the coming years, further highlighting the increasing demand for these professionals as AI adoption continues to expand across various industries.

--> This positive job growth projection signifies a promising career path for individuals with expertise in these areas and suggests that investments in data science and AI research skills will likely yield strong returns in the job market.

"""

# %% [markdown]
# # ⏬ 12. what is the average salary base on job title

# %%
average_salary = ai_job_copy.groupby('Job_Title')['Salary_USD'].mean().reset_index()

plt.figure(figsize=(12, 6))
sns.barplot(x='Job_Title', y='Salary_USD', data=average_salary)
plt.xticks(rotation=45, ha='right')
plt.title('Average Salary by Job Title')
plt.xlabel('Job Title')
plt.ylabel('Average Salary (USD)')
plt.tight_layout()
plt.show()

# %%
"""
Conclusion:

▶️ Average Salary by Job Title:

--> AI Researchers command the highest average salaries within the AI job market, emphasizing the demand for specialized expertise and advanced knowledge in this field.

--> This reflects the critical role of AI Researchers in developing cutting-edge technologies and driving innovation within organizations.

--> While other AI-related roles also offer competitive salaries, the premium placed on AI Research expertise highlights its importance in shaping the future of AI and its potential for high earning potential.

"""

# %% [markdown]
# # ⏬ 13. How many type industries are there at each location and how big ?

# %%
plt.figure(figsize=(12, 8))  # Adjust figure size as needed

sns.heatmap(pd.crosstab(ai_job_copy['Location'], ai_job_copy['Industry']), annot=True, cmap="YlGnBu", fmt="d")

plt.title("Industry Types and Counts Across Locations")
plt.xlabel("Industry")
plt.ylabel("Location")
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
"""
Conclusion:

▶️ Industry Types and Counts Across Locations:

--> The IT industry has a wide presence across multiple locations, suggesting a robust and diverse geographic distribution of AI-related jobs within this sector.

--> This indicates a broad range of career opportunities for AI professionals within the IT industry, with options for working in different geographic areas and experiencing diverse work environments.

--> This geographic diversity within the IT industry's AI landscape offers flexibility and choice for professionals seeking to build their careers in this dynamic field.

"""

# %% [markdown]
# # ⏬ 14. What are the skill requirements in the industry and how much?

# %%
# Group data and calculate skill counts per industry
skill_industry_counts = ai_job_copy.groupby(['Industry', 'Required_Skills'])['Required_Skills'].count().unstack(fill_value=0)

# Create stacked bar chart
skill_industry_counts.plot(kind='bar', stacked=True, figsize=(12, 6))
plt.title('Skill Requirements Across Industries (Stacked Bar Chart)')
plt.xlabel('Industry')
plt.ylabel('Count of Required Skills')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Required Skills', bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.show()

# %%
"""
Conclusion:

▶️ Skill Requirements Across Industries:

--> Different industries value specific skill sets within the AI domain, signifying the need for professionals to adapt their skills and knowledge to industry-specific requirements and applications.

--> For example, the Finance industry may prioritize expertise in financial modeling and risk management using AI, while the Healthcare industry may seek professionals with skills in medical image analysis and drug discovery using AI technologies.

--> This emphasizes the importance of understanding the unique needs and challenges of different industries when pursuing AI-related careers and tailoring one's skill set accordingly.

"""

# %% [markdown]
# # ⏬ 15. What is average salary base on the industry?

# %%
average_salary = ai_job_copy.groupby('Industry')['Salary_USD'].mean().reset_index()

plt.figure(figsize=(12, 6))
sns.barplot(x='Industry', y='Salary_USD', data=average_salary)
plt.xticks(rotation=45, ha='right')
plt.title('Average Salary by Industry')
plt.xlabel('Industry')
plt.ylabel('Average Salary (USD)')
plt.tight_layout()
plt.show()

# %%
"""
Conclusion:

▶️ Average Salary by Industry:

--> Finance and Healthcare offer high average salaries for AI professionals, possibly reflecting the critical and complex nature of AI applications in these domains and the demand for specialized expertise in these areas.

--> This suggests that individuals with AI skills who are interested in working in these industries may have the potential for higher earning potential.

--> This finding highlights the value of acquiring industry-specific knowledge and skills within AI to maximize career opportunities and compensation.

"""

# %% [markdown]
# # ⏬ 16. relation between Industry and Job_Growth_Projection.

# %%
# Group data and calculate the count for each combination
grouped_data = ai_job_copy.groupby(['Industry', 'Job_Growth_Projection'])['Industry'].count().reset_index(name='Count')

# Create the line plot using seaborn
plt.figure(figsize=(12, 6))  # Adjust figure size as needed
sns.lineplot(x='Industry', y='Count', hue='Job_Growth_Projection', data=grouped_data, marker='o')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.title('Relation between Industry and Job Growth Projection')
plt.xlabel('Industry')
plt.ylabel('Count')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))  # Adjust legend as needed
plt.tight_layout()
plt.show()

# %%
"""
Conclusion:

▶️ Industry vs. Job Growth Projection:

--> The IT industry demonstrates strong job growth projections within the AI field, further supporting its long-term potential and the increasing demand for AI professionals within this sector.

--> This indicates that the IT industry is likely to remain a central hub for AI innovation and career growth, offering a wide range of opportunities for individuals with AI-related skills and expertise.

--> This continued growth trajectory within the IT industry's AI landscape emphasizes its importance in shaping the future of AI and its potential to attract top talent in the field.

"""

# %% [markdown]
# # ⏬ 17. Which industries are remote friendly or not ?

# %%
pd.crosstab(ai_job_copy.Industry, ai_job_copy.Remote_Friendly).plot(kind='bar' , figsize=(15,6)  ,color=[ "#00798c", "#d1495b", "#edae49"])
plt.show()

# %%
"""
Conclusion:

▶️ Remote Friendliness by Industry:

--> Many industries in the AI field offer remote work options, signaling a growing trend towards workplace flexibility and the willingness of companies to accommodate remote work arrangements for AI professionals.

--> This trend reflects the increasing demand for AI talent and the recognition that remote work can be an effective way to attract and retain top professionals in a competitive job market.

--> This flexibility in work arrangements can be beneficial for individuals seeking a better work-life balance and greater geographic mobility in their AI careers.

"""

# %% [markdown]
# # ⏬ 18. Does the company's AI influence increase as the company's size increases?

# %%
# Create the plot
plt.figure(figsize=(10, 6))  # Adjust figure size if needed
sns.countplot(x='Company_Size', hue='AI_Adoption_Level', data=ai_job_copy)
plt.title('AI Adoption Level by Company Size')
plt.xlabel('Company Size')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels if needed
plt.legend(title='AI Adoption Level')
plt.tight_layout()
plt.show()

# %%
"""
Conclusion:

▶️ AI Adoption Level by Company Size:

--> Companies of all sizes are exploring or implementing AI, showing widespread adoption across the market and suggesting that AI is no longer limited to large organizations with extensive resources.

--> This indicates that companies of all scales recognize the potential benefits of AI and are actively seeking ways to integrate it into their operations and strategies.

--> This widespread adoption of AI across different company sizes emphasizes the need for professionals with AI skills across a variety of organizational settings, creating a diverse range of career opportunities.

"""

# %% [markdown]
# # ⏬ 19. Does the job growth projection increase as the presence of AI increases in the market?

# %%
# Create the plot
plt.figure(figsize=(10, 6))  # Adjust figure size if needed
sns.countplot(x='Job_Growth_Projection', hue='AI_Adoption_Level', data=ai_job_copy)
plt.title('AI Adoption Level by Job_Growth_Projection')
plt.xlabel('Job_Growth_Projection')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels if needed
plt.legend(title='AI Adoption Level')
plt.tight_layout()
plt.show()

# %%
"""
Conclusion:

▶️ AI Adoption Level by Job Growth Projection:

--> There is a noticeable correlation between AI adoption and job growth, suggesting a positive impact of AI on the job market and the creation of new opportunities for professionals with AI-related skills and expertise.

--> This indicates that as companies increasingly adopt AI technologies, they are also likely to increase their demand for AI professionals to support the implementation, development, and maintenance of these systems.

--> This positive relationship between AI adoption and job growth reinforces the importance of acquiring AI skills to remain competitive in the evolving job market.

"""

# %% [markdown]
# # ⏬ 20. What is average salary per location ?

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Location', y='Salary_USD', data=ai_job_copy)
plt.xticks(rotation=45, ha='right')
plt.title('Salary Distribution by Location')
plt.xlabel('Location')
plt.ylabel('Salary (USD)')
plt.tight_layout()
plt.show()

# %%
"""
Conclusion:

▶️ Salary Distribution by Location:

--> Certain locations, such as San Francisco, offer higher salary ranges for AI professionals, possibly reflecting a higher cost of living and increased competition for talent in these areas.

--> This suggests that individuals seeking higher earning potential within the AI field may consider relocating to these high-demand locations.

--> However, it is also important to consider the cost of living and other factors when evaluating the overall compensation package and career opportunities in different geographic areas.

"""

# %% [markdown]
# # ⏬ 21. Which skill required for the Ai adoption ?

# %%
# Group data and calculate skill counts per AI adoption level
skill_adoption_counts = ai_job_copy.groupby(['AI_Adoption_Level', 'Required_Skills'])['Required_Skills'].count().unstack(fill_value=0)

# Create stacked bar chart
skill_adoption_counts.plot(kind='bar', stacked=True, figsize=(12, 6))
plt.title('Skill Requirements Across AI Adoption Levels (Stacked Bar Chart)')
plt.xlabel('AI Adoption Level')
plt.ylabel('Count of Required Skills')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Required Skills', bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.show()

# %%
"""
Conclusion:

▶️ Skill Requirements by AI Adoption Level:

--> As AI adoption increases within organizations, more specialized skills are required, highlighting the need for continuous learning and upskilling for professionals to remain relevant and competitive in the evolving AI landscape.

--> This suggests that individuals with basic AI knowledge may need to further develop their expertise in specific areas, such as deep learning or natural language processing, to meet the increasing demands of AI-powered organizations.

--> This emphasis on continuous learning highlights the dynamic nature of the AI field and the importance of staying updated with the latest advancements and technologies.

"""

# %% [markdown]
# # ⏬ 22. What is average salary for each skill ?

# %%
# Group data by 'Required_Skills' and calculate the average salary
average_salary_per_skill = ai_job_copy.groupby('Required_Skills')['Salary_USD'].mean().reset_index()

# Create the bar plot
plt.figure(figsize=(12, 6))  # Adjust figure size if needed
sns.barplot(x='Required_Skills', y='Salary_USD', hue="Required_Skills",data=average_salary_per_skill)
plt.title('Average Salary per Required Skill')
plt.xlabel('Required Skill')
plt.ylabel('Average Salary (USD)')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
"""
Conclusion:

▶️ Average Salary by Required Skill:

--> Skills like Machine Learning and Deep Learning are associated with high average salaries within the AI job market, indicating the value of these specialized competencies and the demand for professionals with expertise in these areas.

--> This suggests that individuals who invest in acquiring these advanced skills are likely to be rewarded with higher earning potential and greater career opportunities within the AI field.

--> This finding reinforces the importance of focusing on acquiring in-demand skills to maximize career success and earning potential in the competitive AI landscape.

"""

# %% [markdown]
# # ⏭️ **SUMMARY**
#
# # ⏩ PROJECT SUMMARY: AI-POWERED JOB ANALYSIS
#
# # ⏬ OBJECTIVE:
# - This project analyzed an AI job market dataset to gain insights into current trends, skill demands, salary expectations, and growth projections within the AI field.
#
# # ⏬ METHODOLOGY:
# - The project involved data cleaning, preprocessing, and exploratory data analysis using Python libraries such as Pandas, Matplotlib, Seaborn, and Plotly. Various visualizations, including bar plots, pie charts, heatmaps, and line plots, were employed to uncover patterns and relationships within the data.
#
# # ⏬ KEY FINDINGS:
#
# - Job Market Trends:
#  - Data Science is a dominant job title with strong demand across industries. The IT industry leads in AI adoption and job creation.
# - Skills:
#  - Machine Learning, Python programming, and Deep Learning are highly sought-after skills. Soft skills like communication and problem-solving are also valued.
# - Salaries:
#  - AI Researchers command the highest average salaries, followed by Data Scientists. Finance and Healthcare offer competitive salary ranges.
# - Automation:
#  - Certain job roles face moderate automation risk within the next ten years, emphasizing the need for skill adaptation and continuous learning.
# - Growth:
#  - The AI field exhibits positive job growth projections, particularly for Data Scientists and AI Researchers.
# - Remote Work:
#  - Remote work opportunities are prevalent in many AI-related jobs, offering flexibility and geographical mobility.
# - AI Adoption:
#  - Companies of all sizes are adopting AI, highlighting the technology's widespread impact and increasing demand for AI professionals.
# - Location:
#  - Major tech hubs like San Francisco and New York remain attractive locations for AI jobs, but other regions are emerging as potential hubs for AI talent.
#
# # ⏬ CONCLUSION:
#
# - The AI job market is dynamic and rapidly evolving, offering significant opportunities for individuals with the right skills and expertise.
# - Continuous learning, adaptability, and a focus on in-demand skills are crucial for success in this field. By understanding current trends and industry needs, aspiring AI professionals can position themselves for rewarding careers in this transformative industry.
#
# # ⏬ RECOMMENDATIONS:
#
# - Individuals interested in AI careers should focus on acquiring technical skills like Machine Learning, Deep Learning, and Python programming.
# - Professionals should monitor automation trends and adapt their skills accordingly to remain competitive in the job market.
# - Consider location preferences and salary expectations when evaluating AI job opportunities.
# - Embrace remote work options for greater flexibility and geographic mobility.
# - Stay updated on the latest advancements and technologies in the AI field through continuous learning and upskilling initiatives.
